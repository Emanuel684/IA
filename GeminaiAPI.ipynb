# %% [markdown]
# AIzaSyDovSBTNfU5pO1vCDq6wDUtokRkFbEc6bM

# %%
# curl "https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent?key=GEMINI_API_KEY" \
# -H 'Content-Type: application/json' \
# -X POST \
# -d '{
#   "contents": [{
#     "parts":[{"text": "Explain how AI works"}]
#     }]
#    }'

# %%
# %pip install -q -U google-genai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.7/159.7 kB 4.9 MB/s eta 0:00:00

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
from google import genai

client = genai.Client(api_key="AIzaSyDovSBTNfU5pO1vCDq6wDUtokRkFbEc6bM")

response = client.models.generate_content(
    model="gemini-2.0-flash", contents="¿Cuales son los programas de pregado de ingenieria en UPB Colombia?"
)
to_markdown(response.text)
# Out:
# > La Universidad Pontificia Bolivariana (UPB) en Colombia ofrece una variedad de programas de pregrado en ingeniería en sus diferentes seccionales. A continuación, te presento una lista de los programas disponibles, teniendo en cuenta que la oferta puede variar ligeramente entre seccionales:
# >
# > **UPB Medellín:**
# >
# > *   **Ingeniería Aeronáutica:** Programa enfocado en el diseño, fabricación, operación y mantenimiento de aeronaves.
# > *   **Ingeniería Ambiental:** Se centra en la gestión sostenible de los recursos naturales, la prevención y mitigación de la contaminación.
# > *   **Ingeniería Biomédica:** Aplica principios de ingeniería al campo de la medicina y la biología para desarrollar soluciones innovadoras en salud.
# > *   **Ingeniería Civil:** Forma profesionales capaces de diseñar, construir y mantener infraestructuras civiles como edificios, puentes, carreteras, etc.
# ...

# %%
# !pip install python-docx

from docx import Document

def read_docx(file_path):
  doc = Document(file_path)
  full_text = []
  for para in doc.paragraphs:
    full_text.append(para.text)
  return '\n'.join(full_text)

file_path = "/content/Programas de pregrado y carreras universitarias _ UPB.docx"

text = read_docx(file_path)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 4.0 MB/s eta 0:00:00
# ...

# %%
text
# Out:
# '\n\n\n\n\n\n\n\n\n\nMatrículas abiertas 2025 en UPB\nEstudia en la UPB sin límites, sin excusas\n\n\n\n\n\nConoce nuestra oferta de programas profesionales y empieza a estudiar en una de las universidades más prestigiosas de Latinoamérica.\n\n\n¡Déjanos tus datos y te contactaremos!\n\n*\n*\n*\n*\n\n\n\n\n\n\n\nCalendario académico (https://www.upb.edu.co/ss/es/documentos/doc- calendario-pregrado-2025-1464285463751.pdf)\n\nEstudia tu pregrado en Medellín\n\n\nAdministración de Empresas (https://upb.edu.co/es/pregrados/administracion- empresas-medellin)\nArquitectura (https://upb.edu.co/es/pregrados/arquitectura-medellin) Ciencias Políticas (http://upb.edu.co/es/pregrados/ciencias-politicas-medellin)\nComunicación Social - Periodismo (https://upb.edu.co/es/pregrados/comunicacion- social-periodismo-medellin)\nDerecho  (http://upb.edu.co/es/pregrados/derecho-medellin)\nDiseño Gráfico (http://upb.edu.co/es/pregrados/diseno-grafico-medellin) Diseño de Vestuario (http://upb.edu.co/es/preg
# ...

# %%
response = client.models.generate_content(
    model="gemini-2.0-flash", contents="¿Cuales son los programas de pregado de ingenieria en UPB Colombia?" + text
)
to_markdown(response.text)
# Out:
# > Según la información proporcionada, estos son los programas de pregrado en ingeniería que ofrece la UPB en Colombia, por campus:
# >
# > **Medellín:**
# >
# > *   Ingeniería Ambiental
# > *   Ingeniería en Ciencia de Datos
# > *   Ingeniería Electrónica
# > *   Ingeniería Industrial
# > *   Ingeniería Mecánica
# > *   Ingeniería en Nanotecnología
# > *   Ingeniería Química
# >
# > **Bucaramanga:**
# >
# > *   Ingeniería Civil
# > *   Ingeniería de Sistemas e Informática
# > *   Ingeniería Electrónica
# > *   Ingeniería Industrial
# > *   Ingeniería Mecánica
# >
# > **Palmira:**
# >
# > *   Ingeniería Industrial
# >
# > **Montería:**
# >
# > *   Ingeniería Electrónica
# > *   Ingeniería Industrial
# > *   Ingeniería Mecánica
# > *   Ingeniería Sanitaria y Ambiental
# >
# > **Virtual:**
# >
# > *   Ingeniería de Software
